# %% [markdown]
# ## Process Class

# %%
class Process:
    def __init__(self, name, time, priority=0):
        self.name = name
        self.time = time
        self.priority = priority

def Average(lst, count=0):
    if count == 0:
      return sum(lst) / len(lst)
    return sum(lst) / count

# %% [markdown]
# ## Shortest Job First

# %%
import operator
procss_list = []
input_number = int(input("Enter Number of Process: "))
for i in range(input_number):
    name = "P"+str(i) #input("Name: ")
    time = float(input("Burst Time: "))
    prcs = Process(name, time)
    procss_list.append(prcs)
new_list = sorted(procss_list, key=operator.attrgetter("time"))
procss_list = new_list
init_time = 0
start_time=[]
for p in procss_list:
    start_time.append(init_time)
    print(init_time, end=" - ")
    print(p.name, end=" - " )
    init_time = init_time + p.time
print(init_time)
average_time = Average(start_time)
print("Average Waiting Time:", round(average_time,2)," ms")
# Out:
# Enter Number of Process: 4
# Burst Time: 21
# Burst Time: 3
# Burst Time: 6
# Burst Time: 2
# 0 - P3 - 2.0 - P1 - 5.0 - P2 - 11.0 - P0 - 32.0
# Average Waiting Time: 4.5  ms
